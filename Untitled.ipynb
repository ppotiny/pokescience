# %%
import pandas as pd

pk = pd.read_csv('pokemon_data.csv')

pk.head()
# Out:
#    id     species  generation_id  evolution_chain_id  gender_rate  \
# 0   1   bulbasaur              1                   1            1
# 1   2     ivysaur              1                   1            1
# 2   3    venusaur              1                   1            1
# 3   4  charmander              1                   2            1
# 4   5  charmeleon              1                   2            1
#
#    capture_rate  base_happiness  has_gender_differences  type1   type2  \
# 0            45              70                       0  grass  poison
# 1            45              70                       0  grass  poison
# 2            45              70                       1  grass  poison
# 3            45              70                       0   fire     NaN
# 4            45              70                       0   fire     NaN
#
#    attack  defense  hp  special-attack  special-defense  speed    habitat
# ...

# %%
import seaborn as sns

sns.barplot(x=pk['type1'], y=pk['special-attack'], hue='gender_rate')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-30d52a619076> in <module>()
#       1 import seaborn as sns
#       2
# ----> 3 sns.barplot(x=pk['type1'], y=pk['special-attack'], hue='gender_rate')
#
# C:\Python27\Lib\site-packages\seaborn\categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# C:\Python27\Lib\site-packages\seaborn\categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
# ...
